# %%
# !pip install fastkml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pygeoif: filename=pygeoif-0.7-py3-none-any.whl size=19000 sha256=f64d87d556b97351d2fbccf9550dff9505c45c748052b3da5e85e286e338fd78
#   Stored in directory: /home/hiroshiyaginuma/.var/app/com.jetbrains.PyCharm-Professional/cache/pip/wheels/aa/cf/1b/9fca6daf27ed851b7825721ec783327883ebf05b103cfbecd8
# Successfully built pygeoif
# ...

# %%
from fastkml import kml


class PlaceMark:
    def __init__(self, name, description, latitude, longitude, style):
        self.name: str = name
        self.description: str = description
        self.latitude: float = latitude
        self.longitude: float = longitude
        self.style: str = style

class Kml:
    def __init__(self, filepath):
        self.filepath = filepath
        self.placemarks = []

    def generate_placemark(self):
        with open(self.filepath, 'rt', encoding="utf-8") as the_file:
            doc = the_file.read()
            k = kml.KML()
            k.from_string(doc)
            features = list(k.features())
            feat = list(features[0].features())
            # print(dir(feat[0]._features[0]))
            # print(feat[0]._features[0].styleUrl)
            for pm in feat[0]._features:
                self.placemarks.append(
                    PlaceMark(pm.name, pm.description, pm.geometry.y, pm.geometry.x, pm.styleUrl)
                )
        return self.placemarks
                
kml_inst = Kml('../data/aed_aoba_20221223.kml')
placemarks = kml_inst.generate_placemark()
# print(len(placemarks))
# print(dir(placemarks[0]))
for p in placemarks:
    print(p.name)
    print(p.style)
# print(placemarks)
# Out:
# ＮＴＴドコモ東北
# #icon-22
# 仙台農業協同組合上杉支店
# #icon-22
# 花京院スクエア
# #icon-22
# 仙台合同庁舎
# #icon-22
# 江陽グランドホテル
# #icon-22
# 仙台中央斎場清月記
# #icon-22
# 仙台ロフト
# #icon-22
# ＪＲ仙台駅
# #icon-22
# エスパル
# #icon-22
# 東北総合サービス㈱仙台営業支店
# #icon-22
# ＡＥＲ（アエル）
# #icon-22
# ＪＲあおば通駅
# #icon-22
# 七十七銀行本店営業部
# #icon-22
# 南町通センタービル
# #icon-22
# 仙台パルコ
# #icon-22
# ＪＲ東日本仙台支社
# #icon-22
# ＪＲ仙台病院
# #icon-22
# ㈱河北新報社本社ビル
# #icon-22
# 東北学院大学土樋キャンパス
# #icon-22
# パラディソ二日町店
# #icon-22
# 前田建設工業㈱東北支店
# #icon-22
# フコク生命仙台支社
# #icon-22
# 定禅寺パークビル
# #icon-22
# 東芝仙台ビル
# #icon-22
# 東北公済病院
# #icon-22
# カメイ㈱本社
# #icon-22
# 仙台パークビル
# #icon-22
# 仙台銀行本店
# #icon-22
# ㈱藤崎
# #icon-22
# ＫＵＲＡＸ
# #icon-22
# 電力ビル
# #icon-22
# 三越仙台店
# #icon-22
# 株式会社　一・四・一
# #icon-22
# 早坂愛生会病院
# #icon-22
# 仙台北斎場清月記
# #icon-22
# 台原高柳病院
# #icon-22
# 仙台厚生病院
# #icon-22
# 宮城県予防医学協会付属診療所
# #icon-22
# 東北福祉大学国見キャンパス
# #icon-22
# 国見台病院
# #icon-22
# 東北福祉大学ステーションキャンパス
# #icon-22
# 学校法人東北文化学園大学
# #icon-22
# 宮城学院大学・高校・中学
# #icon-22
# 平成眼科医院
# #icon-22
# セイコーインスツル㈱仙台事業所
# ...

# %%
print(dir(f2[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_address', '_atom_author', '_atom_link', '_features', '_phoneNumber', '_snippet', '_styleUrl', '_styles', '_time_span', '_time_stamp', 'address', 'append', 'append_style', 'author', 'begin', 'description', 'end', 'etree_element', 'extended_data', 'features', 'from_element', 'from_string', 'id', 'isopen', 'link', 'name', 'ns', 'phoneNumber', 'snippet', 'styleUrl', 'styles', 'targetId', 'timeStamp', 'to_string', 'visibility']

# %%
print(f2[0].features())
# Out:
# <generator object _Container.features at 0x7fc6a7221990>

# %%
f2[0]._features

# %%
for i in f2[0]._features:
    # print(dir(i))
    # print(i.geometry)
    # print(dir(i.geometry))
    print(i.name)
    print(i.description)
    print(i.geometry.x)
    print(i.geometry.y)
# Out:
# ＮＴＴドコモ東北
# 青葉区上杉一丁目１－２<br>㈱エヌ・ティ・ティ・ドコモ東北
# 140.873957
# 38.269922
# 仙台農業協同組合上杉支店
# 青葉区上杉一丁目２－１６<br>仙台農業協同組合
# 140.871892
# 38.269454
# 花京院スクエア
# 青葉区花京院一丁目１－２０<br>三菱地所㈱東北支店
# 140.880394
# 38.265466
# 仙台合同庁舎
# 青葉区本町三丁目３－１<br>仙台合同庁舎
# 140.873587
# 38.267702
# 江陽グランドホテル
# 青葉区本町二丁目３－１<br>㈱江陽グランドホテル
# 140.874375
# 38.26328
# 仙台中央斎場清月記
# 青葉区本町二丁目７－４<br>㈱すがわら葬儀社
# 140.874586
# 38.264232
# 仙台ロフト
# 青葉区中央一丁目１０－１０<br>㈱仙台ロフト
# 140.88062
# 38.260154
# ＪＲ仙台駅
# 青葉区中央一丁目１－１<br>東日本旅客鉄道㈱仙台支社
# 140.882031
# 38.260036
# エスパル
# 青葉区中央一丁目１－１<br>仙台ターミナルビル㈱
# 140.881634
# 38.259177
# 東北総合サービス㈱仙台営業支店
# 青葉区中央一丁目１－１<br>東北総合サービス㈱
# 140.882208
# 38.260019
# ＡＥＲ（アエル）
# 青葉区中央一丁目３－１<br>㈱クロップス
# 140.881425
# 38.262665
# ＪＲあおば通駅
# 青葉区中央三丁目２－１<br>東日本旅客鉄道㈱仙台支社　あおば通駅
# 140.878308
# 38.260719
# 七十七銀行本店営業部
# 青葉区中央三丁目３－２０<br>株式会社七十七銀行　本店営業部
# 140.875939
# 38.259874
# 南町通センタービル
# 青葉区中央三丁目４－７<br>三菱地所㈱東北支店　メットライフ仙台ビル
# 140.876905
# 38.259319
# 仙台パルコ
# 青葉区中央一丁目２－３<br>㈱パルコ
# 140.8815704
# 38.2619564
# ＪＲ東日本仙台支社
# ...

# %%
dir(f2[0]._features[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_address',
#  '_atom_author',
#  '_atom_link',
#  '_geometry',
#  '_phoneNumber',
#  '_snippet',
#  '_styleUrl',
#  '_styles',
#  '_time_span',
#  '_time_stamp',
#  'address',
#  'append_style',
#  'author',
#  'begin',
#  'description',
#  'end',
#  'etree_element',
#  'extended_data',
#  'from_element',
#  'from_string',
#  'geometry',
#  'id',
#  'isopen',
#  'link',
#  'name',
#  'ns',
#  'phoneNumber',
#  'snippet',
#  'styleUrl',
#  'styles',
#  'targetId',
#  'timeStamp',
#  'to_string',
#  'visibility']

# %%
f2[0]._features[0].name
f2[0]._features[0].description
# Out:
# '青葉区上杉一丁目１－２<br>㈱エヌ・ティ・ティ・ドコモ東北'

# %%
# !pip install openrouteservice

# %%
import openrouteservice

coords = ((8.34234,48.23424),(8.34423,48.26424))

client = openrouteservice.Client(key='5b3ce3597851110001cf62480a0b07b915894b6b846751c5f6690b88') # Specify your personal API key
routes = client.directions(coords)

print(routes)
# Out:
# {'bbox': [8.327725, 48.231953, 8.345244, 48.263552], 'routes': [{'summary': {'distance': 5477.4, 'duration': 803.6}, 'segments': [{'distance': 5477.4, 'duration': 803.6, 'steps': [{'distance': 247.2, 'duration': 59.3, 'type': 11, 'instruction': 'Head south on Benatweg', 'name': 'Benatweg', 'way_points': [0, 8]}, {'distance': 51.8, 'duration': 12.4, 'type': 6, 'instruction': 'Continue straight onto Benatweg', 'name': 'Benatweg', 'way_points': [8, 10]}, {'distance': 1684.0, 'duration': 134.7, 'type': 1, 'instruction': 'Turn right onto Hölzle, K 5528', 'name': 'Hölzle, K 5528', 'way_points': [10, 64]}, {'distance': 263.7, 'duration': 31.6, 'type': 1, 'instruction': 'Turn right', 'name': '-', 'way_points': [64, 73]}, {'distance': 301.9, 'duration': 36.2, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [73, 85]}, {'distance': 535.6, 'duration': 64.3, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [85, 96]}, {'distance': 248.1, 'duration': 29.8, 'type':
# ...
